# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\rumeysa\appdata\local\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\rumeysa\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\rumeysa\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import xgboost as xgb
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report

veri = pd.read_csv("groq_sentetik_10000_ETIKETLI.csv")

veri = veri.dropna(subset=['orijinal','sentetik', 'label'])



print(f"Toplam {len(veri)} adet veri başarıyla yüklendi.")

df_train, df_test, y_train, y_test = train_test_split(
    veri[['sentetik', 'orijinal']], 
    veri['label'], 
    test_size=0.2, 
    shuffle=False 
)

X_train_metin = df_train['sentetik']

X_test_metin = df_test['orijinal']

vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')

X_train = vectorizer.fit_transform(X_train_metin)

X_test = vectorizer.transform(X_test_metin)

model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42, n_jobs=-1, eval_metric='logloss')
model.fit(X_train, y_train)

sonuc = model.predict(X_test)

print("-" * 50)
print("SONUÇLAR VE METRİKLER (XGBoost) ")
print("-" * 50)

cm = confusion_matrix(y_test, sonuc)
print("Karmaşıklık Matrisi (Confusion Matrix):\n", cm)

dogruluk = accuracy_score(y_test, sonuc)
print(f"\nDoğruluk Değeri (Accuracy): %{dogruluk * 100:.2f}")

kesinlik = precision_score(y_test, sonuc)
duyarlilik = recall_score(y_test, sonuc)
f1 = f1_score(y_test, sonuc)

print(f"Kesinlik (Precision): {kesinlik:.4f}")
print(f"Duyarlılık (Recall): {duyarlilik:.4f}")
print(f"F1 Skoru: {f1:.4f}\n")

print("Sınıflandırma Raporu (Classification Report):")
print(classification_report(y_test, sonuc, target_names=['Sınıf 0', 'Sınıf 1']))
# Out:
# 1. Kendi verisetiniz (CSV) yükleniyor...
# Toplam 10000 adet veri başarıyla yüklendi.
#
# 2. Veri ilk %80 eğitim, son %20 test olacak şekilde sıralı ayrılıyor...
# 3. Metinler sayısallaştırılıyor (TF-IDF)...
# 4. Model eğitiliyor (XGBoost)...
# Not: Gradient Boosting ağaçları sırayla eğittiği için bu işlem biraz zaman alabilir. Lütfen bekleyin...
# 5. Tahminler yapılıyor ve sonuçlar hesaplanıyor...
#
# --------------------------------------------------
# SONUÇLAR VE METRİKLER (XGBoost)
# --------------------------------------------------
# Karmaşıklık Matrisi (Confusion Matrix):
#  [[761 250]
#  [201 788]]
#
# Doğruluk Değeri (Accuracy): %77.45
# Kesinlik (Precision): 0.7592
# Duyarlılık (Recall): 0.7968
# F1 Skoru: 0.7775
#
# Sınıflandırma Raporu (Classification Report):
#               precision    recall  f1-score   support
#
#      Sınıf 0       0.79      0.75      0.77      1011
#      Sınıf 1       0.76      0.80      0.78       989
#
#     accuracy                           0.77      2000
#    macro avg       0.78      0.77      0.77      2000
# weighted avg       0.78      0.77      0.77      2000
